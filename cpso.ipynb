# %%
import numpy as np
import cpso
import optimizationFuncs as optim
from importlib import reload

cpso = reload(cpso)

# %%
dims = 1
llim = np.repeat (-20, dims)
rlim = np.repeat (20, dims)
func = optim.anuwu

# %%
hecu = cpso.HECS_PSO(func, llim, rlim, 25)
opt = hecu.optimize()
print("\n{}".format(opt))

# %%
plain = cpso.PWLC_PSO(func, llim, rlim, 25)
opt = plain.optimize()
print("\n{}".format(opt))

# %%
plain = cpso.GB_PSO(func, llim, rlim, 25)
opt = plain.optimize()
print("\n{}".format(opt))

# %%
plain.initParticles()
print(plain.velocity.shape)
